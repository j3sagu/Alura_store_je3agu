# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
tienda["Precio"] = tienda["Precio"].round(0).astype(int)
tienda2["Precio"] = tienda2["Precio"].round(0).astype(int)
tienda3["Precio"] = tienda3["Precio"].round(0).astype(int)
tienda4["Precio"] = tienda4["Precio"].round(0).astype(int)

sumaVentas = tienda["Precio"].sum()
print(f"La suma de las ventas de la primera tienda es de: ${sumaVentas} pesos mexicanos")
sumaVentas2 = tienda2["Precio"].sum()
print(f"La suma de las ventas de la segunda tienda es de: ${sumaVentas2} pesos mexicanos")
sumaVentas3 = tienda3["Precio"].sum()
print(f"La suma de las ventas totales de la tercera tienda es de: ${sumaVentas3} pesos mexicanos")
sumaVentas4 = tienda4["Precio"].sum()
print(f"La suma de las ventas totales de la cuarta tienda es de: ${sumaVentas4} pesos mexicanos")
ventasTotales = sumaVentas + sumaVentas2 + sumaVentas3 + sumaVentas4
print(f"El total de las ventas en total de las 4 tiendas es de: ${ventasTotales} pesos mexicanos")

print("Ahora un gráfico en el cual se observa un comparativo de las ventas de las tiendas:")

ingresos = [
    sumaVentas,
    sumaVentas2,
    sumaVentas3,
    sumaVentas4,
]

tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
colores = ['#4dffea', '#faff99', '#23520f', '#4d2d0d']

plt.figure(figsize=(8, 5))
barras = plt.bar(tiendas, ingresos, color=colores)

plt.title('Ingresos x tienda')
plt.xlabel('Tiendas')
plt.ylabel('Pesos mexicanos')

for i, ingreso in enumerate(ingresos):
    plt.text(i, ingreso + ingreso * 0.01, f"${int(ingreso):,}", ha='center', fontsize=9)

plt.tight_layout()
plt.show()
# Out:
# La suma de las ventas de la primera tienda es de: $1150880400 pesos mexicanos
# La suma de las ventas de la segunda tienda es de: $1116343500 pesos mexicanos
# La suma de las ventas totales de la tercera tienda es de: $1098019600 pesos mexicanos
# La suma de las ventas totales de la cuarta tienda es de: $1038375700 pesos mexicanos
# El total de las ventas en total de las 4 tiendas es de: $4403619200 pesos mexicanos
# Ahora un gráfico en el cual se observa un comparativo de las ventas de las tiendas:

# %% [markdown]
# # 2. Ventas por categoría

# %%
tiendas = [tienda, tienda2, tienda3, tienda4]
tienda_nombres = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

for nombre_tienda, tienda in zip(tienda_nombres, tiendas):
    print(f"\n{nombre_tienda}:\n")

    ventasCategoria = tienda.groupby('Categoría del Producto').agg(
        Cantidad_Ventas=('Precio', 'count'),
        Recaudado_Total=('Precio', 'sum')
    ).reset_index().sort_values(by='Cantidad_Ventas', ascending=False)
    print(ventasCategoria)

    plt.figure(figsize=(10, 6))
    plt.bar(ventasCategoria['Categoría del Producto'], ventasCategoria['Cantidad_Ventas'])
    plt.title(f'Distribución de ventas por categoría - {nombre_tienda}')
    plt.xlabel('Categoría del Producto')
    plt.ylabel('Cantidad de Ventas')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# Tienda 1:
#
#     Categoría del Producto  Cantidad_Ventas  Recaudado_Total
# 7                  Muebles              465        187633700
# 3             Electrónicos              448        429493500
# 5                 Juguetes              324         17995700
# 2        Electrodomésticos              312        363685200
# 1     Deportes y diversión              284         39290000
# 4   Instrumentos musicales              182         91299000
# 6                   Libros              173          8784900
# 0  Artículos para el hogar              171         12698400
# Tienda 2:
#
#     Categoría del Producto  Cantidad_Ventas  Recaudado_Total
# 7                  Muebles              442        176426300
# 3             Electrónicos              422        410831100
# 5                 Juguetes              313         15945400
# 2        Electrodomésticos              305        348567800
# 1     Deportes y diversión              275         34744500
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
valoracionPromedioT1 = round(tienda["Calificación"].mean(), 2)
valoracionPromedioT2 = round(tienda2["Calificación"].mean(), 2)
valoracionPromedioT3 = round(tienda3["Calificación"].mean(), 2)
valoracionPromedioT4 = round(tienda4["Calificación"].mean(), 2)
print(f"La calificación promedio de la tienda 1 fué: {valoracionPromedioT1}")
print(f"La calificación promedio de la tienda 2 fué: {valoracionPromedioT2}")
print(f"La calificación promedio de la tienda 3 fué: {valoracionPromedioT3}")
print(f"La calificación promedio de la tienda 4 fué: {valoracionPromedioT4}")
print("La satisfacción de los clientes en promedio para las tiendas va sobre 4 de un total de 5 puntos!")
# Out:
# La calificación promedio de la tienda 1 fué: 4.0
# La calificación promedio de la tienda 2 fué: 4.04
# La calificación promedio de la tienda 3 fué: 4.05
# La calificación promedio de la tienda 4 fué: 4.0
# La satisfacción de los clientes en promedio para las tiendas va sobre 4 de un total de 5 puntos!

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
def mostrar_ventas_y_recaudacion(nombre_tienda, df):

    ventas = df["Producto"].value_counts()


    recaudacion = df.groupby("Producto")["Precio"].sum()

    resumen = pd.DataFrame({
        "CantidadVendida": ventas,
        "RecaudacionTotal": recaudacion
    }).sort_values("CantidadVendida", ascending=False)

    resumen.index = resumen.index.astype(str)


    top_5 = resumen.head(5)
    bottom_5 = resumen.tail(5)

    print(f"\n{nombre_tienda.upper()}")
    print("\nTop 5 productos más vendidos:")
    print(top_5)
    print("\nTop 5 productos menos vendidos:")
    print(bottom_5)


    plt.figure(figsize=(14, 6))

    plt.subplot(1, 2, 1)
    ax1 = plt.gca()
    top_5["CantidadVendida"].plot(kind="bar", color="skyblue", edgecolor='black', ax=ax1)
    ax1.set_ylabel("Cantidad Vendida")
    ax1.set_ylim(0, top_5["CantidadVendida"].max() + 1)

    ax2 = ax1.twinx()
    ax2.plot(top_5.index, top_5["RecaudacionTotal"], color='blue', marker='o', linestyle='-', linewidth=2)
    ax2.set_ylabel("Recaudación ($)", color='blue')
    ax2.tick_params(axis='y', labelcolor='blue')
    plt.title(f'Top 5 más vendidos - {nombre_tienda}')


    plt.subplot(1, 2, 2)
    ax1 = plt.gca()
    bottom_5["CantidadVendida"].plot(kind="bar", color="salmon", edgecolor='black', ax=ax1)
    ax1.set_ylabel("Cantidad Vendida")
    ax1.set_ylim(0, bottom_5["CantidadVendida"].max() + 1)

    ax2 = ax1.twinx()
    ax2.plot(bottom_5.index, bottom_5["RecaudacionTotal"], color='red', marker='o', linestyle='-', linewidth=2)
    ax2.set_ylabel("Recaudación ($)", color='red')
    ax2.tick_params(axis='y', labelcolor='red')
    plt.title(f'Top 5 menos vendidos - {nombre_tienda}')

    plt.tight_layout()
    plt.show()


mostrar_ventas_y_recaudacion("Tienda 1", tienda)
mostrar_ventas_y_recaudacion("Tienda 2", tienda2)
mostrar_ventas_y_recaudacion("Tienda 3", tienda3)
mostrar_ventas_y_recaudacion("Tienda 4", tienda4)
# Out:
# TIENDA 1
#
# Top 5 productos más vendidos:
#                            CantidadVendida  RecaudacionTotal
# Producto
# Cama box                                62          32946300
# Cubertería                              59           2649300
# Cama king                               56          37555400
# Dashboards con Power BI                 56           1990600
# Carrito de control remoto               55           4014200
#
# Top 5 productos menos vendidos:
#                              CantidadVendida  RecaudacionTotal
# Producto
# Ciencia de datos con Python               38           2108800
# Refrigerador                              38          75271900
# Guitarra acústica                         37          11257100
# Armario                                   34          16421400
# Guitarra eléctrica                        33          25823100
# TIENDA 2
#
# Top 5 productos más vendidos:
#                            CantidadVendida  RecaudacionTotal
# Producto
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
def costo_envio_promedio(nombre_tienda, df):
    promedio = df["Costo de envío"].mean()
    print(f"Costo de envío promedio en {nombre_tienda}: ${promedio:.2f}")


costo_envio_promedio("Tienda 1", tienda)
costo_envio_promedio("Tienda 2", tienda2)
costo_envio_promedio("Tienda 3", tienda3)
costo_envio_promedio("Tienda 4", tienda4)
# Out:
# Costo de envío promedio en Tienda 1: $23459.46
# Costo de envío promedio en Tienda 2: $25216.24
# Costo de envío promedio en Tienda 3: $24805.68
# Costo de envío promedio en Tienda 4: $23459.46

# %%
import numpy as np

tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]
dataframes = [tienda, tienda2, tienda3, tienda4]

promedios_envio = [df["Costo de envío"].mean() for df in dataframes]
cantidad_envios = [len(df) for df in dataframes]

y = np.arange(len(tiendas))
ancho = 0.35


max_valor = max(max(cantidad_envios), max(promedios_envio))
espacio_extra = max_valor * 0.2

plt.figure(figsize=(10, 6))

# Use a colormap for rainbow effect for both sets of bars
colors_cantidad = plt.cm.viridis(y / len(tiendas))
colors_promedio = plt.cm.plasma(y / len(tiendas))


b1 = plt.barh(y - ancho/2, cantidad_envios, height=ancho, label="Cantidad de envíos", color=colors_cantidad, edgecolor='black')
b2 = plt.barh(y + ancho/2, promedios_envio, height=ancho, label="Costo envío promedio ($)", color=colors_promedio, edgecolor='black')

plt.xlim(0, max_valor + espacio_extra)

plt.xlabel("Valores")
plt.yticks(y, tiendas)
plt.title("Cantidad de envíos y costo promedio por tienda")
plt.legend(loc='best')

for bar in b1:
    width = bar.get_width()
    plt.text(width + 3, bar.get_y() + bar.get_height()/2, f"{int(width)}", va='center')

for bar in b2:
    width = bar.get_width()
    plt.text(width + 0.5, bar.get_y() + bar.get_height()/2, f"${width:.2f}", va='center')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Informe

# %% [markdown]
# Aquí te dejo una versión **minimalista y congruente** con un análisis estadístico:
#
# ---
#
# # Informe de Análisis de Tiendas
#
# ### Comparativa
#
# | Métrica        | Tienda 1 | Tienda 2 | Tienda 3 | Tienda 4 |
# | -------------- | -------- | -------- | -------- | -------- |
# | Ingresos       | Alto     | Medio    | Medio    | Bajo     |
# | Calificación   | \~4.0    | \~4.0    | \~4.0    | \~4.0    |
# | Costo de Envío | Bajo     | Medio    | Alto     | Bajo     |
# | Potencial      | Medio    | Medio    | Alto     | Bajo     |
#
# ---
#
# ### Conclusión
#
# La **Tienda 4** es la más recomendable para vender porque:
#
# * Presenta los ingresos más bajos
# * No destaca en ninguna métrica
# * Mantiene bajo costo de envío
# * Su operación es simple
#
# ---
